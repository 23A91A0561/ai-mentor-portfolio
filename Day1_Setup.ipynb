# %% [markdown]
# <a href="https://colab.research.google.com/github/23A91A0561/ai-mentor-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines the progressive skill sets needed for a comprehensive AI professional:
#
# *   **Foundational & Data Skills:** The base layer, encompassing programming (Python/R), math, statistics, and the ability to collect, clean, and prepare data.
# *   **Machine Learning Engineering:** Focuses on developing, training, evaluating, and deploying core machine learning models and MLOps practices.
# *   **AI Specialization:** Expertise in advanced, specific AI domains such as Deep Learning (e.g., neural networks, transformers), Natural Language Processing, Computer Vision, or Generative AI.
# *   **AI Strategy & Ethics:** The top layer, dealing with business understanding, problem framing, ethical implications, responsible AI deployment, and project management.
